# %% [markdown]
# ### Read AS data

# %%
import pandas as pd

file_path = 'ensembl.txt'
dat = pd.read_csv(file_path)  # Specify the delimiter if it's not a comma-separated file

dat.head(20)
# Out:
#     seqname   source     feature     start       end score strand frame  \
# 0         1  Ensembl  similarity  55039733  55040044  1051      +     .
# 1         1  Ensembl  similarity  55039838  55040044   921      +     .
# 2         1  Ensembl  similarity  55039838  55040044   787      +     .
# 3         1  Ensembl  similarity  55039838  55040044   893      +     .
# 4         1  Ensembl  similarity  55039838  55040044   891      +     .
# 5         1  Ensembl  similarity  55039838  55040044   893      +     .
# 6         1  Ensembl  similarity  55039838  55040044   902      +     .
# 7         1  Ensembl  similarity  55039838  55040044   689      +     .
# 8         1  Ensembl  similarity  55039838  55040044   576      +     .
# 9         1  Ensembl  similarity  55039838  55040044   875      +     .
# 10        1  Ensembl  similarity  55039838  55040044   912      +     .
# 11        1  Ensembl  similarity  55039838  55040044   579      +     .
# 12        1  Ensembl  similarity  55039838  55040044   907      +     .
# 13        1  Ensembl  similarity  55039838  55040044   696      +     .
# 14        1  Ensembl  similarity  55039838  55040044   688      +     .
# 15        1  Ensembl  similarity  55039838  55040044   912      +     .
# 16        1  Ensembl  similarity  55039838  55040044   806      +     .
# 17        1  Ensembl  similarity  55039862  55040044   561      +     .
# 18        1  Ensembl  similarity  55039868  55040044   447      +     .
# 19        1  Ensembl  similarity  55039982  55040044   308      +     .
#
#          hid  hstart   hend genscan gene_id transcript_id exon_id gene_type  \
# 0   H2N797.2    85.0  186.0     NaN     NaN           NaN     NaN       NaN
# 1   B4DEZ9.1     1.0   69.0     NaN     NaN           NaN     NaN       NaN
# 2   F7BM04.1     1.0   67.0     NaN     NaN           NaN     NaN       NaN
# 3   G3S2C5.1     1.0   67.0     NaN     NaN           NaN     NaN       NaN
# 4   K7B7Q7.1     1.0   71.0     NaN     NaN           NaN     NaN       NaN
# 5   A8T650.1     1.0   67.0     NaN     NaN           NaN     NaN       NaN
# 6   K7BKH3.1     1.0   69.0     NaN     NaN           NaN     NaN       NaN
# 7   L9KYI8.1     1.0   67.0     NaN     NaN           NaN     NaN       NaN
# 8   Q80W65.2     1.0   72.0     NaN     NaN           NaN     NaN       NaN
# 9   A8T658.1     1.0   67.0     NaN     NaN           NaN     NaN       NaN
# 10  Q8NBP7.3     1.0   69.0     NaN     NaN           NaN     NaN       NaN
# 11  H0VTV9.1     1.0   67.0     NaN     NaN           NaN     NaN       NaN
# 12  A8T655.2     1.0   69.0     NaN     NaN           NaN     NaN       NaN
# 13  I3LGB2.1     1.0   67.0     NaN     NaN           NaN     NaN       NaN
# 14  I3M601.1     1.0   69.0     NaN     NaN           NaN     NaN       NaN
# 15  A8T644.1     1.0   69.0     NaN     NaN           NaN     NaN       NaN
# 16  G3QLV4.1     1.0   56.0     NaN     NaN           NaN     NaN       NaN
# 17  P59996.1     7.0   68.0     NaN     NaN           NaN     NaN       NaN
# 18  H3AN22.1     5.0   59.0     NaN     NaN           NaN     NaN       NaN
# 19  H2L850.1     1.0   22.0     NaN     NaN           NaN     NaN       NaN
#
#    variation_name  probe_name
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# 5             NaN         NaN
# 6             NaN         NaN
# 7             NaN         NaN
# 8             NaN         NaN
# 9             NaN         NaN
# 10            NaN         NaN
# 11            NaN         NaN
# 12            NaN         NaN
# 13            NaN         NaN
# 14            NaN         NaN
# 15            NaN         NaN
# 16            NaN         NaN
# 17            NaN         NaN
# 18            NaN         NaN
# 19            NaN         NaN

# %%
dat.tail(20)
# Out:
#       seqname   source feature     start       end score strand frame  hid  \
# 8445        1  Ensembl    gene  55063369  55064852     .      +     0  NaN
# 8446        1  Ensembl    gene  55056261  55056805     .      +    -1  NaN
# 8447        1  Ensembl    gene  55057331  55057514     .      +     0  NaN
# 8448        1  Ensembl    gene  55058036  55058209     .      +     1  NaN
# 8449        1  Ensembl    gene  55058499  55058647     .      +     1  NaN
# 8450        1  Ensembl    gene  55059486  55059663     .      +     0  NaN
# 8451        1  Ensembl    gene  55061375  55061556     .      +     1  NaN
# 8452        1  Ensembl    gene  55063369  55064852     .      +     0  NaN
# 8453        1  Ensembl    gene  55039838  55040044     .      +     0  NaN
# 8454        1  Ensembl    gene  55043843  55044034     .      +     0  NaN
# 8455        1  Ensembl    gene  55046523  55046646     .      +     0  NaN
# 8456        1  Ensembl    gene  55052278  55052411     .      +     1  NaN
# 8457        1  Ensembl    gene  55052650  55052791     .      +     0  NaN
# 8458        1  Ensembl    gene  55055993  55056189     .      +     1  NaN
# 8459        1  Ensembl    gene  55057331  55057514     .      +     0  NaN
# 8460        1  Ensembl    gene  55058036  55058209     .      +     1  NaN
# 8461        1  Ensembl    gene  55058499  55058647     .      +     1  NaN
# 8462        1  Ensembl    gene  55059486  55059663     .      +     0  NaN
# 8463        1  Ensembl    gene  55061375  55061556     .      +     1  NaN
# 8464        1  Ensembl    gene  55063369  55063584     .      +     0  NaN
#
#       hstart  hend genscan       gene_id         transcript_id  \
# 8445     NaN   NaN     NaN  gene-PCSK9.1     rna-NM_174936.4.1
# 8446     NaN   NaN     NaN  gene-PCSK9.1  rna-XM_047417050.1.1
# 8447     NaN   NaN     NaN  gene-PCSK9.1  rna-XM_047417050.1.1
# 8448     NaN   NaN     NaN  gene-PCSK9.1  rna-XM_047417050.1.1
# 8449     NaN   NaN     NaN  gene-PCSK9.1  rna-XM_047417050.1.1
# 8450     NaN   NaN     NaN  gene-PCSK9.1  rna-XM_047417050.1.1
# 8451     NaN   NaN     NaN  gene-PCSK9.1  rna-XM_047417050.1.1
# 8452     NaN   NaN     NaN  gene-PCSK9.1  rna-XM_047417050.1.1
# 8453     NaN   NaN     NaN   CCDS603.1.1           CCDS603.1.1
# 8454     NaN   NaN     NaN   CCDS603.1.1           CCDS603.1.1
# 8455     NaN   NaN     NaN   CCDS603.1.1           CCDS603.1.1
# 8456     NaN   NaN     NaN   CCDS603.1.1           CCDS603.1.1
# 8457     NaN   NaN     NaN   CCDS603.1.1           CCDS603.1.1
# 8458     NaN   NaN     NaN   CCDS603.1.1           CCDS603.1.1
# 8459     NaN   NaN     NaN   CCDS603.1.1           CCDS603.1.1
# 8460     NaN   NaN     NaN   CCDS603.1.1           CCDS603.1.1
# 8461     NaN   NaN     NaN   CCDS603.1.1           CCDS603.1.1
# 8462     NaN   NaN     NaN   CCDS603.1.1           CCDS603.1.1
# 8463     NaN   NaN     NaN   CCDS603.1.1           CCDS603.1.1
# 8464     NaN   NaN     NaN   CCDS603.1.1           CCDS603.1.1
#
#                     exon_id       gene_type variation_name  probe_name
# 8445    exon-NM_174936.4-12  protein_coding            NaN         NaN
# 8446  exon-XM_047417050.1-1  protein_coding            NaN         NaN
# 8447     exon-NM_174936.4-7  protein_coding            NaN         NaN
# 8448     exon-NM_174936.4-8  protein_coding            NaN         NaN
# 8449     exon-NM_174936.4-9  protein_coding            NaN         NaN
# 8450    exon-NM_174936.4-10  protein_coding            NaN         NaN
# 8451    exon-NM_174936.4-11  protein_coding            NaN         NaN
# 8452    exon-NM_174936.4-12  protein_coding            NaN         NaN
# 8453             CCDS603.11       ccds_gene            NaN         NaN
# 8454             CCDS603.12       ccds_gene            NaN         NaN
# 8455             CCDS603.13       ccds_gene            NaN         NaN
# 8456             CCDS603.14       ccds_gene            NaN         NaN
# 8457             CCDS603.15       ccds_gene            NaN         NaN
# 8458             CCDS603.16       ccds_gene            NaN         NaN
# 8459             CCDS603.17       ccds_gene            NaN         NaN
# 8460             CCDS603.18       ccds_gene            NaN         NaN
# 8461             CCDS603.19       ccds_gene            NaN         NaN
# 8462            CCDS603.110       ccds_gene            NaN         NaN
# 8463            CCDS603.111       ccds_gene            NaN         NaN
# 8464            CCDS603.112       ccds_gene            NaN         NaN

# %% [markdown]
# ### subset non-coding variant coordinates and with gene ID PCSK9

# %%
df = dat[dat['gene_type'] != "protein_coding"].copy()

# %%
df.head(20)
# Out:
#       seqname   source     feature     start       end score strand frame  \
# 0           1  Ensembl  similarity  55039733  55040044  1051      +     .
# 1           1  Ensembl  similarity  55039838  55040044   921      +     .
# 2           1  Ensembl  similarity  55039838  55040044   787      +     .
# 3           1  Ensembl  similarity  55039838  55040044   893      +     .
# 4           1  Ensembl  similarity  55039838  55040044   891      +     .
# ...       ...      ...         ...       ...       ...   ...    ...   ...
# 8460        1  Ensembl        gene  55058036  55058209     .      +     1
# 8461        1  Ensembl        gene  55058499  55058647     .      +     1
# 8462        1  Ensembl        gene  55059486  55059663     .      +     0
# 8463        1  Ensembl        gene  55061375  55061556     .      +     1
# 8464        1  Ensembl        gene  55063369  55063584     .      +     0
#
#            hid  hstart   hend genscan      gene_id transcript_id      exon_id  \
# 0     H2N797.2    85.0  186.0     NaN          NaN           NaN          NaN
# 1     B4DEZ9.1     1.0   69.0     NaN          NaN           NaN          NaN
# 2     F7BM04.1     1.0   67.0     NaN          NaN           NaN          NaN
# 3     G3S2C5.1     1.0   67.0     NaN          NaN           NaN          NaN
# 4     K7B7Q7.1     1.0   71.0     NaN          NaN           NaN          NaN
# ...        ...     ...    ...     ...          ...           ...          ...
# 8460       NaN     NaN    NaN     NaN  CCDS603.1.1   CCDS603.1.1   CCDS603.18
# 8461       NaN     NaN    NaN     NaN  CCDS603.1.1   CCDS603.1.1   CCDS603.19
# 8462       NaN     NaN    NaN     NaN  CCDS603.1.1   CCDS603.1.1  CCDS603.110
# 8463       NaN     NaN    NaN     NaN  CCDS603.1.1   CCDS603.1.1  CCDS603.111
# 8464       NaN     NaN    NaN     NaN  CCDS603.1.1   CCDS603.1.1  CCDS603.112
#
#       gene_type variation_name  probe_name
# 0           NaN            NaN         NaN
# 1           NaN            NaN         NaN
# 2           NaN            NaN         NaN
# 3           NaN            NaN         NaN
# 4           NaN            NaN         NaN
# ...         ...            ...         ...
# 8460  ccds_gene            NaN         NaN
# 8461  ccds_gene            NaN         NaN
# 8462  ccds_gene            NaN         NaN
# 8463  ccds_gene            NaN         NaN
# 8464  ccds_gene            NaN         NaN
#
# [8347 rows x 18 columns]

# %% [markdown]
# ## Read gnomAD PCSK9 gene variants data

# %%
import csv

filename = 'gnomAD_v2.1.1_ENSG00000169174_2023_09_21_22_52_39.csv'

# Read the CSV file into a DataFrame
gf = pd.read_csv(filename)

# Display the first few rows of the DataFrame
print(gf[['Chromosome', 'Position', 'rsIDs', 'Transcript']].head(20))
# Out:
#     Chromosome  Position         rsIDs         Transcript
# 0            1  55505447    rs45448095  ENST00000302118.5
# 1            1  55505452   rs576575389  ENST00000302118.5
# 2            1  55505457   rs545454601  ENST00000302118.5
# 3            1  55505457   rs545454601  ENST00000302118.5
# 4            1  55505462  rs1043549074  ENST00000302118.5
# 5            1  55505463  rs1193796116  ENST00000302118.5
# 6            1  55505464  rs1269395517  ENST00000302118.5
# 7            1  55505466  rs1365420733  ENST00000302118.5
# 8            1  55505469  rs1473950917  ENST00000302118.5
# 9            1  55505477   rs576535214  ENST00000302118.5
# 10           1  55505482  rs1389098623  ENST00000302118.5
# 11           1  55505483   rs376542717  ENST00000302118.5
# 12           1  55505485    rs28362202  ENST00000302118.5
# 13           1  55505488  rs1393600693  ENST00000302118.5
# 14           1  55505489  rs1387827816  ENST00000302118.5
# 15           1  55505499   rs182393980  ENST00000302118.5
# 16           1  55505500  rs1298619732  ENST00000302118.5
# 17           1  55505501  rs1341655436  ENST00000302118.5
# 18           1  55505503   rs886039837  ENST00000302118.5
# 19           1  55505507  rs1357021576  ENST00000302118.5

# %% [markdown]
# ### Merge AS data with gnomAD PCSK9 gene variants based on the Position

# %%
import pandas as pd

# Sample data
data1 = gf
df1 = pd.DataFrame(data1)

data2 = df
df2 = pd.DataFrame(data2)


# List to store merged rows
merged_rows = []

# Loop through each row in df1 and df2
for index1, row1 in df1.iterrows():
    for index2, row2 in df2.iterrows():
        if row2['start'] <= row1['Position'] <= row2['end']:
            # Combine the rows
            combined_row = row1.to_dict()
            combined_row.update(row2.to_dict())
            merged_rows.append(combined_row)

# Convert merged rows to DataFrame
merged_df = pd.DataFrame(merged_rows)

merged_df[['Position', 'start', 'end']]

print(merged_df)
